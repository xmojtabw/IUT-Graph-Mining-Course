# %% [markdown]
# # HW1 - Graph Mining

# %% [markdown]
# ## Prepare Phase
#
# > This notebook is designed to be run in a local environment. If you rather a google colab notebook use `HW1_40131383_colab.ipynb`.
#
# > Note: This phase involves adding the datasets and libraries. Please install use `pipenv install` to install the required libraries and `pipenv shell` to activate the virtual environment. Be carefull to use this environment as kernel for this notebook.
#
# > This notebook should be run from Homework1 directory. Otherwise it can't find the datasets.

# %%
# !pip install -i https://pypi.org/simple  graphviz==0.21  matplotlib==3.10.7 networkx==3.5 numpy==2.3.4
